# %%
# !pip install cv2
# !pip install opencv-python
# !pip install matplotlib
# !pip install numpy
# !pip install cvlib
# !pip3 install --upgrade opencv-python==4.5.5.64

# %% [markdown]
# # Новый раздел

# %%
import cv2
import json
import matplotlib.pyplot as plt
import numpy as np
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

# %%
img = cv2.imread('20.jpg')
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(img1)
plt.show()

# %%
box, label, count = cv.detect_common_objects(img)
output = draw_bbox(img1, box, label, count)

# %%
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(output)
plt.show()

# %% [markdown]
# подготовка каждого изображения

# %%
import os
 
for filename in os.listdir(path = 'D:\images'):
        if filename[filename.rfind(".") + 1:] in ['jpg', 'jpeg', 'png']:
                img = cv2.imread(filename)
                img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                path = os.path.join('D:\images_after', 'test.jpg')
                img1.save(path)
